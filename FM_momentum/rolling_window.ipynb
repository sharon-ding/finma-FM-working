# %% [markdown]
# ## **Rolling Window Momentum Trading Strategy using Nasdaq-100**
#
# **What is a Rolling Window Strategy?**
# Instead of selecting top and bottom performers based on a fixed period, this strategy **re-evaluates** the best and worst performers at regular intervals (e.g., monthly or quarterly).
#
# **Key Benefits:**
# - Adapts to changing market conditions.
# - Improves timing of entry/exit decisions.
# - Mimics real-world systematic trading more closely.

# %% [markdown]
# ## **Initial Setup**
# Here we load required libraries, set up dates, and prepare the historical price dataset `hPricesDT` that contains the adjusted close prices for the Nasdaq-100 stocks.

# %%
pip install yfinance pandas matplotlib numpy requests lxml
# Out:
# Requirement already satisfied: yfinance in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.0)
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: numpy in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: lxml in /usr/local/python/3.12.1/lib/python3.12/site-packages (6.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/codespace/.local/lib/python3.12/site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from yfinance) (6.33.4)
# Requirement already satisfied: websockets>=13.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in /home/codespace/.local/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /home/codespace/.local/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import requests

# %%
# get all the tables from the wikipedia page 'https://en.wikipedia.org/wiki/Nasdaq-100#Components'
nasdaq = 'https://en.wikipedia.org/wiki/Nasdaq-100#Components'
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0 Safari/537.36"
    )
}
response = requests.get(nasdaq, headers=headers, timeout=30)
response.raise_for_status()

# write the scraped tables to a pandas dataframe called WikipediaDTs
WikipediaDTs = pd.read_html(nasdaq, storage_options=headers)
len(WikipediaDTs) # this will tell us how many tables there are on the page
tickersLIST = WikipediaDTs[4]['Ticker'].tolist()

# download from yahoo finance the historical data for all tickers in the list and put it in a single dataframe called hPricesDT
hPricesDT = pd.DataFrame()
hPricesDT = yf.download(tickersLIST, start='2010-07-01', end='2021-06-30')['Close']

# identify any tickers with NaN values and list them in a list called tickersNaN
tickersNaN = []
for ticker in tickersLIST:
    if hPricesDT[ticker].isnull().values.any() == True:
        tickersNaN.append(ticker)
hPricesDT.drop(tickersNaN, axis=1, inplace=True) # drop the tickers with NaN values from the dataframe hPricesDT

hPricesDT.head()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# /home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# $GEHC: possibly delisted; no price data found  (1d 2010-07-01 -> 2021-06-30) (Yahoo error = "Data doesn't exist for startDate = 1277956800, endDate = 1625025600")
# [*                      2%                       ]  2 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*                      3%                       ]  3 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**                     4%                       ]  4 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**                     5%                       ]  5 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [***                    6%                       ]  6 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [***                    7%                       ]  7 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [****                   8%                       ]  8 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*****                 10%                       ]  10 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*****                 11%                       ]  11 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [******                12%                       ]  12 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [******                13%                       ]  13 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*******               14%                       ]  14 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*******               15%                       ]  15 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [********              16%                       ]  16 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [********              17%                       ]  17 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********             18%                       ]  18 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********             19%                       ]  19 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# $ARM: possibly delisted; no price data found  (1d 2010-07-01 -> 2021-06-30) (Yahoo error = "Data doesn't exist for startDate = 1277956800, endDate = 1625025600")
# [**********            21%                       ]  21 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [***********           22%                       ]  22 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [***********           23%                       ]  23 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [************          24%                       ]  24 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [************          25%                       ]  25 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [************          26%                       ]  26 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*************         27%                       ]  27 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*************         28%                       ]  28 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**************        29%                       ]  29 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**************        30%                       ]  30 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [***************       31%                       ]  31 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [***************       32%                       ]  32 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [****************      33%                       ]  33 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [****************      34%                       ]  34 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*****************     35%                       ]  35 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*****************     36%                       ]  36 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [******************    37%                       ]  37 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [******************    38%                       ]  38 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*******************   39%                       ]  39 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*******************   40%                       ]  40 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [********************  41%                       ]  41 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [********************  42%                       ]  42 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [********************* 43%                       ]  43 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [********************* 44%                       ]  44 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************45%                       ]  45 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************46%                       ]  46 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************47%                       ]  47 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************48%                       ]  48 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************49%                       ]  49 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************50%                       ]  50 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************50%                       ]  51 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************51%                       ]  52 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************52%                       ]  53 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************53%                       ]  54 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************54%*                      ]  55 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************55%*                      ]  56 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************56%**                     ]  57 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************57%**                     ]  58 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************58%***                    ]  59 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************59%***                    ]  60 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************60%****                   ]  61 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************61%****                   ]  62 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************62%*****                  ]  63 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************63%*****                  ]  64 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************64%******                 ]  65 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************65%******                 ]  66 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************66%*******                ]  67 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************67%*******                ]  68 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************68%********               ]  69 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************69%********               ]  70 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************70%*********              ]  71 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************71%*********              ]  72 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************72%**********             ]  73 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************73%**********             ]  74 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************74%***********            ]  75 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************75%***********            ]  76 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************76%***********            ]  77 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************77%************           ]  78 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************78%************           ]  79 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************79%*************          ]  80 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************80%*************          ]  81 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************81%**************         ]  82 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************82%**************         ]  83 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************83%***************        ]  84 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************84%***************        ]  85 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************85%****************       ]  86 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************86%****************       ]  87 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************87%*****************      ]  88 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************88%*****************      ]  89 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************89%******************     ]  90 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************90%******************     ]  91 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************91%*******************    ]  92 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************92%*******************    ]  93 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************93%********************   ]  94 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************94%********************   ]  95 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************95%*********************  ]  96 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************96%*********************  ]  97 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [**********************97%********************** ]  98 of 101 completed/home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# $CEG: possibly delisted; no price data found  (1d 2010-07-01 -> 2021-06-30) (Yahoo error = "Data doesn't exist for startDate = 1277956800, endDate = 1625025600")
# [*********************100%***********************]  101 of 101 completed
#
# 3 Failed downloads:
# ['GEHC', 'ARM', 'CEG']: possibly delisted; no price data found  (1d 2010-07-01 -> 2021-06-30) (Yahoo error = "Data doesn't exist for startDate = 1277956800, endDate = 1625025600")
# Ticker          AAPL       ADBE        ADI        ADP       ADSK        AEP  \
# Date
# 2010-07-01  7.452174  26.660000  19.586470  24.245821  24.570000  17.832960
# 2010-07-02  7.405991  26.730000  19.551390  24.074865  24.309999  17.927053
# 2010-07-06  7.456674  26.340000  19.565422  24.062651  24.049999  18.408573
# 2010-07-07  7.757783  26.790001  20.652784  24.551115  24.730000  19.022943
# 2010-07-08  7.740386  26.850000  20.400232  24.648813  24.610001  19.244326
#
# Ticker       ALNY      AMAT   AMD       AMGN  ...        TRI      TSLA  TTWO  \
# Date                                          ...
# 2010-07-01  15.04  9.349631  7.39  35.429535  ...  24.009630  1.464000  8.85
# 2010-07-02  15.17  9.349631  7.17  35.211609  ...  24.002953  1.280000  9.01
# 2010-07-06  15.06  9.178220  7.04  34.939182  ...  24.183041  1.074000  8.91
# 2010-07-07  15.42  9.497663  7.39  35.007301  ...  24.509832  1.053333  9.75
# 2010-07-08  15.65  9.435332  7.37  35.572567  ...  24.643221  1.164000  9.39
#
# Ticker            TXN       VRSK       VRTX        WBD        WDC        WMT  \
# Date
# 2010-07-01  15.412803  28.863590  32.299999  18.441492  18.726862  11.685333
# 2010-07-02  15.372892  28.796696  32.220001  18.083801  18.255362  11.603144
# 2010-07-06  15.379552  28.720236  32.169998  18.206438  18.055889  11.740930
# 2010-07-07  16.131224  28.271036  33.040001  18.533470  18.908203  11.825539
# 2010-07-08  16.111273  28.108561  33.799999  18.564129  19.077463  11.888390
#
# Ticker            XEL
# Date
# 2010-07-01  12.192387
# 2010-07-02  12.245597
# 2010-07-06  12.393422
# 2010-07-07  12.635853
# 2010-07-08  12.771848
#
# [5 rows x 80 columns]

# %% [markdown]
# ## **Simulate and Track Results**
# Using the functionality created below, we can get the data, determine best/worst performers, plot their price movements and then generate simulated portfolio performance.
#
# This is the core logic of the notebook.
#
# The loop steps forward in increments of the given window, performing the following steps at each interval:
# 1. **Signal Window:** Looks back over the given window length in days to calculate returns.
# 2. **Select Stocks:** Picks the top 5 (long) and bottom 5 (short) performers.
# 3. **Portfolio Construction:** Allocates equal capital across selected stocks.
# 4. **Track Performance:** Multiplies price data by share count to compute portfolio value.
#
# This simulates rebalancing the strategy periodically.

# %%
def get_signal_data(hPricesDT, signal_start_date, signal_months):
    # convert signal_start_date to a timestamp
    signal_start_date = pd.Timestamp(signal_start_date)
    
    # calculate signal_end_date as 1 year after signal_start_date
    signal_end_date = signal_start_date + pd.DateOffset(months=signal_months) + pd.DateOffset(days=-1)

    # create a dataframe called signalDT that contains the prices for the signal period
    signalDT = hPricesDT[signal_start_date:signal_end_date]

    # convert the prices to index values and put them in a dataframe called signalIndexDT
    signalIndexDT = signalDT / signalDT.iloc[0]

    # reset the signal dates to the first and last dates in the signalIndexDT dataframe index (noting that holidays and weekends will be skipped)
    signal_start_date = signalIndexDT.index[0]
    signal_end_date = signalIndexDT.index[-1]

    return signalDT, signalIndexDT, signal_start_date, signal_end_date

def get_top_bottom_tickers(signalDT, signalIndexDT, numPositions):
    # create a list of the top performing tickers and bottom performing tickers with the highest index numbers at the end of the period
    topPerformers = signalIndexDT.iloc[-1].nlargest(numPositions).index.tolist()
    bottomPerformers = signalIndexDT.iloc[-1].nsmallest(numPositions).index.tolist()
    otherTickers = signalIndexDT.columns.tolist()
    for ticker in topPerformers:
        otherTickers.remove(ticker)
    for ticker in bottomPerformers:
        otherTickers.remove(ticker)
    
    return topPerformers, bottomPerformers, otherTickers

def plot_signal_period(hPricesIDX, topPerformers, bottomPerformers, otherTickers):
    # create a dataframe called signalIndexDT that contains the index values for all tickers
    signalIndexDT = hPricesIDX / hPricesIDX.iloc[0]

    # plot the index for all tickers in the dataframe signalIndexDT
    plt.figure(figsize=(20,10))
    for ticker in topPerformers:
        plt.plot(signalIndexDT[ticker], color='green')
        plt.text(signalIndexDT.index[-1], signalIndexDT[ticker].iloc[-1], ticker, fontsize=12)
    for ticker in bottomPerformers:
        plt.plot(signalIndexDT[ticker], color='red')
        plt.text(signalIndexDT.index[-1], signalIndexDT[ticker].iloc[-1], ticker, fontsize=12)
    for ticker in otherTickers:
        plt.plot(signalIndexDT[ticker], color='lightgrey', linewidth='0.5')
    plt.xlabel('Date', fontsize=18)
    plt.xticks(fontsize=13)
    plt.ylabel('Price Index', fontsize=18)
    plt.yticks(fontsize=13)
    plt.title('Signal period performance - top and bottom performers', fontsize=22)
    # plot gridlines
    plt.grid(which='major', axis='both', linestyle='--')
    plt.show()

    # print the index values for the top performing tickers and bottom performing tickers
    print('Top performing tickers:')
    print(signalIndexDT[topPerformers].iloc[-1])
    print('Bottom performing tickers:')
    print(signalIndexDT[bottomPerformers].iloc[-1])

def get_long_short_portfolios(signalDT, signal_start_date, opening_portfolio_value, topPerformers, bottomPerformers, numPositions):
    # create a dataframe called longPORT that contains the long portfolio
    topPrices = signalDT.iloc[-1][topPerformers].tolist()
    topshareCount = opening_portfolio_value / numPositions / np.array(topPrices)
    longPORTinput = {'Ticker': topPerformers, 'Price': topPrices, 'ShareCount': topshareCount}
    longPORT = pd.DataFrame(longPORTinput)
    longPORT.set_index('Ticker', inplace=True)

    # create a dataframe called shortPORT that contains the short portfolio
    bottomPrices = signalDT.iloc[-1][bottomPerformers].tolist()
    bottomshareCount = opening_portfolio_value / numPositions / np.array(bottomPrices)
    shortPORTinput = {'Ticker': bottomPerformers, 'Price': bottomPrices, 'ShareCount': bottomshareCount}
    shortPORT = pd.DataFrame(shortPORTinput)
    shortPORT.set_index('Ticker', inplace=True)

    return shortPORT, longPORT
    
def run_portfolio_performance(longPORT, shortPORT, hPricesDT, trading_start_date, trading_months):
    # convert trading_start_date to a timestamp
    trading_start_date = pd.Timestamp(trading_start_date)
    
    # calculate trading_end_date as 1 year after trading_start_date
    trading_end_date = trading_start_date + pd.DateOffset(months=trading_months) + pd.DateOffset(days=-1)

    # calculate the values of the long and short portfolios over the trading period
    longPORT_values = hPricesDT[trading_start_date:trading_end_date][longPORT.index]*longPORT['ShareCount']
    shortPORT_values = hPricesDT[trading_start_date:trading_end_date][shortPORT.index]*shortPORT['ShareCount']

    # calculate the total portfolio value for each day
    longPORT_values['Total'] = longPORT_values.sum(axis=1)
    shortPORT_values['Total'] = shortPORT_values.sum(axis=1)

    return longPORT_values, shortPORT_values

def plot_portfolio_performance(longPort_values, shortPort_values, trading_start_date, trading_months, portfolioSize):
    # calculate trading end date
    trading_end_date = trading_start_date + pd.DateOffset(months=trading_months) + pd.DateOffset(days=-1)

    # calculate benchmark portfolio values during the trading period
    ndx = yf.download(
        '^NDX',
        start=trading_start_date,
        end=trading_end_date
    )['Close']
    ndx_rebased = ndx / ndx.iloc[0] * portfolioSize
    ndx_rebased = ndx_rebased.squeeze()

    # compare the performance of the long and short portfolio
    fig, ax = plt.subplots(figsize=(20, 10))

    longPort_values['Total'].plot(ax=ax)
    shortPort_values['Total'].plot(ax=ax)
    ndx_rebased.plot(ax=ax, linestyle='--')

    ax.set_xlabel('Date')
    ax.set_ylabel('Portfolio Value')
    ax.set_title('Portfolio Value')
    ax.legend(['Long', 'Short', 'Benchmark'])

    plt.show()

# %% [markdown]
# ## **Strategy Evaluation**
#
# We then evaluate the strategy by simulating its use from June 2017 with $10,000, a 6 month signal and 12 total trading months.

# %%
signal_start_date = '2017-06-01'
numPositions = 10
signal_months = 6
trading_months = 12
portfolioSize = 10000

signalDT, signalIndexDT, signal_start_date, signal_end_date = get_signal_data(hPricesDT, signal_start_date, signal_months)
topPerformers, bottomPerformers, otherPerformers = get_top_bottom_tickers(signalDT, signalIndexDT, numPositions)
plot_signal_period(signalDT, topPerformers, bottomPerformers, otherPerformers)
shortPORT, longPORT = get_long_short_portfolios(signalDT, signal_start_date, portfolioSize, topPerformers, bottomPerformers, numPositions)
print(longPORT)
print(shortPORT)
longPort_values, shortPort_values = run_portfolio_performance(longPORT, shortPORT, hPricesDT, signal_end_date, trading_months)
plot_portfolio_performance(longPort_values, shortPort_values, signal_end_date, trading_months, portfolioSize)
# Out:
# Top performing tickers:
# Ticker
# INSM    1.999359
# ALNY    1.930273
# ODFL    1.439038
# TTWO    1.427931
# NVDA    1.392534
# MU      1.378088
# CPRT    1.357660
# ASML    1.311711
# ISRG    1.304935
# ADBE    1.283562
# Name: 2017-11-30 00:00:00, dtype: float64
# Bottom performing tickers:
# Ticker
# WBD      0.711294
# MSTR     0.735506
# REGN     0.776490
# BKR      0.776796
# WDC      0.870630
# DXCM     0.874046
# TMUS     0.899411
# TSLA     0.907395
# CMCSA    0.908563
# SBUX     0.915901
# Name: 2017-11-30 00:00:00, dtype: float64
#              Price  ShareCount
# Ticker
# INSM     31.190001   32.061558
# ALNY    134.539993    7.432734
# ODFL     41.549164   24.067873
# TTWO    111.550003    8.964590
# NVDA      4.962156  201.525293
# MU       41.359787   24.178074
# CPRT     10.790000   92.678406
# ASML    162.217255    6.164572
# ISRG    133.259995    7.504128
# ADBE    181.470001    5.510553
#              Price  ShareCount
# Ticker
# WBD      19.020000   52.576234
# MSTR     13.676000   73.120797
# REGN    359.864136    2.778827
# BKR      23.741285   42.120719
# WDC      54.131992   18.473364
# DXCM     14.607500   68.457984
# TMUS     59.000088   16.949127
# TSLA     20.590000   48.567265
# CMCSA    28.386688   35.227780
# SBUX     48.560024   20.593070
# /home/codespace/.local/lib/python3.12/site-packages/yfinance/scrapers/history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## **Further Evaluation**
#
# Examining the histogram of returns helps us better understand the distribution of outcomes from the strategy. In an ideal world, the strategy would never produce losses. However, a more realistic goal is for the strategy to have larger and more frequent gains than losses.
#
# To evaluate this, we will:
# - Simulate the trading strategy,
# - Plot a histogram of its returns, and
# - Review key summary statistics such as the mean and standard deviation.
#
# This will give us insight into both the consistency and volatility of the strategy’s performance.

# %%
numPositions = 10
signal_months = 6
trading_months = 12
portfolioSize = 1000000

# create a pandas dataframe called portfolioPerformance with 3 columns: 'Long_outcome', 'Short_outcome', 'Long-Short'
portfolioPerformance = pd.DataFrame(columns=['Long_outcome', 'Short_outcome', 'Long-Short'])

rolling_period_start_dates = hPricesDT.index[0:-trading_months]                       # start date to signal end date 

# loop through each trading period and calculate the portfolio performance
for signal_start_date in rolling_period_start_dates:
    signalDT, signalIndexDT, signal_start_date, signal_end_date = get_signal_data(hPricesDT, signal_start_date, signal_months)
    topPerformers, bottomPerformers, otherPerformers = get_top_bottom_tickers(signalDT, signalIndexDT, numPositions)
    shortPORT, longPORT = get_long_short_portfolios(signalDT, signal_start_date, portfolioSize, topPerformers, bottomPerformers, numPositions)
    longPort_values, shortPort_values = run_portfolio_performance(longPORT, shortPORT, hPricesDT, signal_end_date, trading_months)
    portfolioPerformance.loc[signal_start_date] = [longPort_values.iloc[-1]['Total'], shortPort_values.iloc[-1]['Total'], longPort_values.iloc[-1]['Total']-shortPort_values.iloc[-1]['Total']]

# show a histogram of the 'Long-Short' column
portfolioPerformance['Long-Short'].hist(bins=100)
plt.xlabel('Portfolio Value')
plt.ylabel('Frequency')
plt.title('Strategy Profit Distribution')
plt.show()

# %%
# calculate the mean and standard deviation of the 'Long-Short' column
mean = portfolioPerformance['Long-Short'].mean()
std = portfolioPerformance['Long-Short'].std()
print(mean, std)
# Out:
# -8841.710264476376 323405.13750436006
